# %% [markdown]
# <a href="https://colab.research.google.com/github/cchen2612-hub/115-1/blob/main/411414892_H2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello\nhello")
# Out:
# hello
# hello

# %%
print("2026","09",sep="/")
# Out:
# 2026/09

# %%
a=5
b=2.5
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
x=20
y=30
temp=x
x=y
y=temp
print(x,y)
# Out:
# 30 20

# %%
t=5
h=5
print(id(h))
# Out:
# 10446536

# %%
x=50000*(1+0.015)**5
print(x)
# Out:
# 53864.20019421873

# %%
a=11
b=12
print("{}\n{}".format(a,b))
# Out:
# 11
# 12

# %%
a=11
b=12
print("{e}\n{f}".format(e=a,f=b))
# Out:
# 11
# 12

# %%
a=11.123456
print("{0}".format(a))
print(f"{a}")
# Out:
# 11.123456
# 11.123456

# %%
x=float(input("請輸入數字:"))
print(x)
# Out:
# 請輸入數字:10.2
# 10.2

# %%
x=int(input("請輸入目前金幣數量:"))
y=int(input("請輸入獲得金幣數量:"))
z=(x+y)
print(f"任務完成！你現在有{z}枚金幣")
# Out:
# 請輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成！你現在有750枚金幣
